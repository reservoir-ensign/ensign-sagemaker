# %% [markdown]
# # ENSIGN SageMaker
#
# ENSIGN on SageMaker allows you to run our scalable decompositions in the cloud. Start by importing the `cp_apr_cloud` function.

# %%
from ensign.cp_apr_cloud import cp_apr_cloud

# %% [markdown]
# To use the function, you need to specify the following parameters:
# * `job_name` A unique identifier for this compute job.
# * `hyperparameters` A dictionary including the relevant tensor construction and decomposition parameters. The only required hyperparameters are `filepaths` and `rank`. Get more info on these parameters in the ENSIGN User Guide.
# * `s3_input_path` A path to a directory in S3 where your input data has been uploaded. All paths specified in the `filepath` hyperparameter are relative to this path.
# * `s3_output_path` A path to a ditrectory in S3 where the decomposition output will be uploaded.
# * `role_arn` The ARN of an AWS role that includes the `AmazonSageMakerFullAccess` permission.
# * `region_name` The name of region where this job will be executed. Ideally this will be close to the region where the S3 input bucket lives.
# * `instance_type` The name of a SageMaker Training instance on which to perform the compute job.
# * `volume_size_gb` Number of gigabytes of storage to assign to the compute instance. This must be large enough to hold the input dataset.
# * `max_runtime_seconds` The number of seconds after which the compute job will be killed.

# %%
cp_apr_cloud(
    job_name="brendans-job-hello-4",
    hyperparameters={
        "filepaths": "dns_example.csv",
        "rank": "10",
        "columns": "ts,id.orig_h,id.resp_h,id.resp_p",
        "types": "timestamp,str,str,str",
        "binning": "minute,none,none,none"
    },
    s3_input_path="s3://ensign-aws/datasets/dns_example/",
    s3_output_path="s3://ensign-aws/sagemaker_outputs/dns_example/",
    role_arn="arn:aws:iam::998216925257:role/sagemaker_admin_ensign",
    region_name="us-east-1",
    instance_type="ml.m4.xlarge",
    volume_size_gb=1,
    max_runtime_seconds=3600
)
# Out:
# [2021-09-16 11:50:52.859080] Starting
# [2021-09-16 11:53:32.332558] Downloading
# [2021-09-16 11:53:49.536372] Training
# [2021-09-16 11:56:15.651000] 2021-09-16 15:56:13,869 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:13,869 sagemaker-training-toolkit INFO     Failed to parse hyperparameter filepaths value dns_example.csv to Json.
# [2021-09-16 11:56:15.652000] Returning the value itself
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:13,869 sagemaker-training-toolkit INFO     Failed to parse hyperparameter types value timestamp,str,str,str to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:13,869 sagemaker-training-toolkit INFO     Failed to parse hyperparameter entries value count to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:13,870 sagemaker-training-toolkit INFO     Failed to parse hyperparameter columns value ts,id.orig_h,id.resp_h,id.resp_p to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:13,870 sagemaker-training-toolkit INFO     Failed to parse hyperparameter binning value minute,none,none,none to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,310 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,311 sagemaker-training-toolkit INFO     Failed to parse hyperparameter filepaths value dns_example.csv to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,311 sagemaker-training-toolkit INFO     Failed to parse hyperparameter types value timestamp,str,str,str to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,311 sagemaker-training-toolkit INFO     Failed to parse hyperparameter entries value count to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,311 sagemaker-training-toolkit INFO     Failed to parse hyperparameter columns value ts,id.orig_h,id.resp_h,id.resp_p to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,311 sagemaker-training-toolkit INFO     Failed to parse hyperparameter binning value minute,none,none,none to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,326 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,326 sagemaker-training-toolkit INFO     Failed to parse hyperparameter filepaths value dns_example.csv to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,326 sagemaker-training-toolkit INFO     Failed to parse hyperparameter types value timestamp,str,str,str to Json.
# [2021-09-16 11:56:15.652000] 2021-09-16 15:56:15,326 sagemaker-training-toolkit INFO     Failed to parse hyperparameter entries value count to Json.
# [2021-09-16 11:56:15.653000] 2021-09-16 15:56:15,326 sagemaker-training-toolkit INFO     Failed to parse hyperparameter columns value ts,id.orig_h,id.resp_h,id.resp_p to Json.
# [2021-09-16 11:56:15.653000] Returning the value itself
# [2021-09-16 11:56:15.653000] 2021-09-16 15:56:15,327 sagemaker-training-toolkit INFO     Failed to parse hyperparameter binning value minute,none,none,none to Json.
# [2021-09-16 11:56:15.653000] 2021-09-16 15:56:15,339 sagemaker-training-toolkit INFO     Invoking user script
#
# [2021-09-16 11:56:15.653000] Training Env:
#
# [2021-09-16 11:56:15.653000] {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "filepaths": "dns_example.csv",
#         "types": "timestamp,str,str,str",
#         "entries": "count",
#         "columns": "ts,id.orig_h,id.resp_h,id.resp_p",
#         "max_inner_iter": 5,
#         "rank": 10,
#         "binning": "minute,none,none,none",
#         "max_outer_iter": 50,
#         "stop_tol": 0.0001
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "brendans-job-hello-4",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# [2021-09-16 11:56:15.653000] }
#
# [2021-09-16 11:56:15.653000] Environment variables:
#
# [2021-09-16 11:56:15.653000] SM_HOSTS=["algo-1"]
# [2021-09-16 11:56:15.653000] SM_NETWORK_INTERFACE_NAME=eth0
# [2021-09-16 11:56:15.653000] SM_HPS={"binning":"minute,none,none,none","columns":"ts,id.orig_h,id.resp_h,id.resp_p","entries":"count","filepaths":"dns_example.csv","max_inner_iter":5,"max_outer_iter":50,"rank":10,"stop_tol":0.0001,"types":"timestamp,str,str,str"}
# [2021-09-16 11:56:15.653000] SM_USER_ENTRY_POINT=train.py
# [2021-09-16 11:56:15.654000] SM_FRAMEWORK_PARAMS={}
# [2021-09-16 11:56:15.654000] SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# [2021-09-16 11:56:15.654000] SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# [2021-09-16 11:56:15.654000] SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# [2021-09-16 11:56:15.654000] SM_CHANNELS=["training"]
# [2021-09-16 11:56:15.654000] SM_CURRENT_HOST=algo-1
# [2021-09-16 11:56:15.654000] SM_MODULE_NAME=train
# [2021-09-16 11:56:15.654000] SM_LOG_LEVEL=20
# [2021-09-16 11:56:15.654000] SM_FRAMEWORK_MODULE=
# [2021-09-16 11:56:15.654000] SM_INPUT_DIR=/opt/ml/input
# [2021-09-16 11:56:15.654000] SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# [2021-09-16 11:56:15.654000] SM_OUTPUT_DIR=/opt/ml/output
# [2021-09-16 11:56:15.654000] SM_NUM_CPUS=4
# [2021-09-16 11:56:15.654000] SM_NUM_GPUS=0
# [2021-09-16 11:56:15.654000] SM_MODEL_DIR=/opt/ml/model
# [2021-09-16 11:56:15.654000] SM_MODULE_DIR=/opt/ml/code
# [2021-09-16 11:56:15.654000] SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":null,"hosts":["algo-1"],"hyperparameters":{"binning":"minute,none,none,none","columns":"ts,id.orig_h,id.resp_h,id.resp_p","entries":"count","filepaths":"dns_example.csv","max_inner_iter":5,"max_outer_iter":50,"rank":10,"stop_tol":0.0001,"types":"timestamp,str,str,str"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"brendans-job-hello-4","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# [2021-09-16 11:56:15.654000] SM_USER_ARGS=["--binning","minute,none,none,none","--columns","ts,id.orig_h,id.resp_h,id.resp_p","--entries","count","--filepaths","dns_example.csv","--max_inner_iter","5","--max_outer_iter","50","--rank","10","--stop_tol","0.0001","--types","timestamp,str,str,str"]
# [2021-09-16 11:56:15.654000] SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# [2021-09-16 11:56:15.654000] SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# [2021-09-16 11:56:15.654000] SM_HP_FILEPATHS=dns_example.csv
# [2021-09-16 11:56:15.654000] SM_HP_TYPES=timestamp,str,str,str
# [2021-09-16 11:56:15.654000] SM_HP_ENTRIES=count
# [2021-09-16 11:56:15.654000] SM_HP_COLUMNS=ts,id.orig_h,id.resp_h,id.resp_p
# [2021-09-16 11:56:15.654000] SM_HP_MAX_INNER_ITER=5
# [2021-09-16 11:56:15.655000] SM_HP_RANK=10
# [2021-09-16 11:56:15.655000] SM_HP_BINNING=minute,none,none,none
# [2021-09-16 11:56:15.655000] SM_HP_MAX_OUTER_ITER=50
# [2021-09-16 11:56:15.655000] SM_HP_STOP_TOL=0.0001
# [2021-09-16 11:56:15.655000] PYTHONPATH=/opt/ml/code:/root/anaconda3/bin:/ENSIGN-43/ENSIGN_4.3/Ensign-Py3:/root/anaconda3/lib/python37.zip:/root/anaconda3/lib/python3.7:/root/anaconda3/lib/python3.7/lib-dynload:/root/anaconda3/lib/python3.7/site-packages
#
# [2021-09-16 11:56:15.655000] Invoking script with the following command:
#
# [2021-09-16 11:56:15.655000] /root/anaconda3/bin/python train.py --binning minute,none,none,none --columns ts,id.orig_h,id.resp_h,id.resp_p --entries count --filepaths dns_example.csv --max_inner_iter 5 --max_outer_iter 50 --rank 10 --stop_tol 0.0001 --types timestamp,str,str,str
#
#
# [2021-09-16 11:56:19.662000] CONFIGURATION:
# [2021-09-16 11:56:19.662000] {'filepaths': ['dns_example.csv'], 'rank': 10, 'max_outer_iter': 50, 'max_inner_iter': 5, 'stop_tol': 0.0001, 'columns': ['ts', 'id.orig_h', 'id.resp_h', 'id.resp_p'], 'types': ['timestamp', 'str', 'str', 'str'], 'binning': ['minute', 'none', 'none', 'none'], 'sort': None, 'entries': 'count', 'fuse_columns': None, 'fuse_delimiter': '__', 'header': None}
#
# [2021-09-16 11:56:19.662000] SM_CHANNEL_TRAINING: /opt/ml/input/data/training SM_MODEL_DIR: /opt/ml/model
# [2021-09-16 11:56:19.662000] Filepaths arg: ['/opt/ml/input/data/training/dns_example.csv']
# [2021-09-16 11:56:19.662000] ls /opt/ml/input/data/training: ['dns_example.csv']
#
# [2021-09-16 11:56:19.662000] Reading /opt/ml/input/data/training/dns_example.csv ...
# [2021-09-16 11:56:19.662000] Dataframe has 1 partitions
# [2021-09-16 11:56:19.662000] Building tensor ...
# [2021-09-16 11:56:19.662000] Validating ...
# [2021-09-16 11:56:19.662000] Filtering ...
# [2021-09-16 11:56:19.663000] Binning ...
#   Binning mode 0 (minute)
#   Binning mode 1 (none)
#   Binning mode 2 (none)
#   Binning mode 3 (none)
# [2021-09-16 11:56:19.663000] Fusing ...
# [2021-09-16 11:56:19.663000] Calculating tensor entries ...
# [2021-09-16 11:56:25.154612] Uploading
# [2021-09-16 11:56:20.663000] Constructing labels ...
# [2021-09-16 11:56:20.663000] Building sparse tensor ...
# [2021-09-16 11:56:20.663000] Built tensor in 1.9137213230133057 seconds
# [2021-09-16 11:56:21.664000] {"order": 4, "nnz": 1702, "mode_sizes": [61, 70, 21, 4], "mode_names": ["ts", "id.orig_h", "id.resp_h", "id.resp_p"]}
# [2021-09-16 11:56:21.664000] {"rank": 10, "order": 4, "weights": [4445.141534200424, 1693.734114342816, 1179.0000000000002, 972.3551147959765, 872.5192084344768, 637.9999967329721, 240.25003149332144, 91.99999999999997, 71.99999999999999, 49.0]}
# [2021-09-16 11:56:21.664000] {'time': 0.09307003021240234, 'fit': 0.7294033635141473, 'cosine_sim': 0.9642916002165712, 'norm_scaling': 0.908786375906671, 'coverage': 1.0, 'cp_total_iter': 0}
#
#
#  ** Reached maximum iterations **
#  *** Final Fit = 0.7294033635141473 ***
#  *** Norm Scaling = 0.908786375906671 ***
#  *** Cosine Similarity = 0.9642916002165712 ***
#  *** Final loglikelihood = 13958.75934768034 ***
#  *** Final KKT violation = 0.02754242590848355 ***
#  *** Coverage = 1 ***
# [2021-09-16 11:56:21.664000] 2021-09-16 15:56:21,604 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# [2021-09-16 11:56:31.606648] Completed
# {'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:998216925257:training-job/brendans-job-hello-4', 'ResponseMetadata': {'RequestId': '24c2b41a-c3b0-45a3-8b2b-d15dbcb47047', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '24c2b41a-c3b0-45a3-8b2b-d15dbcb47047', 'content-type': 'application/x-amz-json-1.1', 'content-length': '95', 'date': 'Thu, 16 Sep 2021 15:50:50 GMT'}, 'RetryAttempts': 0}}
